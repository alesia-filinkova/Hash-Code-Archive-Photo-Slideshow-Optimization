# %% [markdown]
# # Comparison of slideshow creating methods

# %%
from usefull_functions import (total_score,
     create_vertical_slides,
     load_photos_from_json)
from vertical_photos_combining_methods import  (random_pair_vertical_photos,
     similar_pair_vertical_photos,
     different_pair_vertical_photos)
from slideshow_creating_methods import (random_slideshow,
                                        nearest_neighbor_slideshow,
                                        grouped_slideshow,
                                        mixed_slideshow)
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Random method

# %% [markdown]
# ### Random Vertical photos

# %%
v_photos = load_photos_from_json("../data/vertical_photos.json")
h_slides = load_photos_from_json("../data/horizontal_photos.json")
v_slides = create_vertical_slides(random_pair_vertical_photos, v_photos)
slides = v_slides + h_slides
slideshow = random_slideshow(slides)
score = total_score(slideshow)
print(score)
# Out:
# 174829

# %% [markdown]
# ### Similar Vertical photos

# %%
v_photos = load_photos_from_json("../data/vertical_photos.json")
h_slides = load_photos_from_json("../data/horizontal_photos.json")
v_slides = create_vertical_slides(similar_pair_vertical_photos, v_photos)
slides = v_slides + h_slides
slideshow = random_slideshow(slides)
score = total_score(slideshow)
print(score)
# Out:
# 141494

# %% [markdown]
# ### Different Vertical photos

# %%
v_photos = load_photos_from_json("../data/vertical_photos.json")
h_slides = load_photos_from_json("../data/horizontal_photos.json")
v_slides = create_vertical_slides(different_pair_vertical_photos, v_photos)
slides = v_slides + h_slides
slideshow = random_slideshow(slides)
score = total_score(slideshow)
print(score)
# Out:
# 187609

# %% [markdown]
# ## Nearest neighbor (greedy) method

# %% [markdown]
# ### Random Vertical photos

# %%
v_photos = load_photos_from_json("../data/vertical_photos.json")
h_slides = load_photos_from_json("../data/horizontal_photos.json")
v_slides = create_vertical_slides(random_pair_vertical_photos, v_photos)
slides = v_slides + h_slides
slideshow = nearest_neighbor_slideshow(slides)
score = total_score(slideshow)
print(score)
# Out:
# 342730

# %% [markdown]
# ### Similar Vertical photos

# %%
v_photos = load_photos_from_json("../data/vertical_photos.json")
h_slides = load_photos_from_json("../data/horizontal_photos.json")
v_slides = create_vertical_slides(similar_pair_vertical_photos, v_photos)
slides = v_slides + h_slides
slideshow = nearest_neighbor_slideshow(slides)
score = total_score(slideshow)
print(score)
# Out:
# 302256

# %% [markdown]
# ### Different Vertical photos

# %%
v_photos = load_photos_from_json("../data/vertical_photos.json")
h_slides = load_photos_from_json("../data/horizontal_photos.json")
v_slides = create_vertical_slides(different_pair_vertical_photos, v_photos)
slides = v_slides + h_slides
slideshow = nearest_neighbor_slideshow(slides)
score = total_score(slideshow)
print(score)
# Out:
# 371787

# %% [markdown]
# ## Grouping by tags

# %% [markdown]
# ### Random Vertical photos

# %%
v_photos = load_photos_from_json("../data/vertical_photos.json")
h_slides = load_photos_from_json("../data/horizontal_photos.json")
v_slides = create_vertical_slides(random_pair_vertical_photos, v_photos)
slides = v_slides + h_slides
slideshow = grouped_slideshow(slides)
score = total_score(slideshow)
print(score)
# Out:
# 224602

# %% [markdown]
# ### Similar Vertical photos

# %%
v_photos = load_photos_from_json("../data/vertical_photos.json")
h_slides = load_photos_from_json("../data/horizontal_photos.json")
v_slides = create_vertical_slides(similar_pair_vertical_photos, v_photos)
slides = v_slides + h_slides
slideshow = grouped_slideshow(slides)
score = total_score(slideshow)
print(score)
# Out:
# 192229

# %% [markdown]
# ### Different Vertical photos

# %%
v_photos = load_photos_from_json("../data/vertical_photos.json")
h_slides = load_photos_from_json("../data/horizontal_photos.json")
v_slides = create_vertical_slides(different_pair_vertical_photos, v_photos)
slides = v_slides + h_slides
slideshow = grouped_slideshow(slides)
score = total_score(slideshow)
print(score)
# Out:
# 241378

# %% [markdown]
# ## Mixed method

# %% [markdown]
# ### Random Vertical photos

# %%
v_photos = load_photos_from_json("../data/vertical_photos.json")
h_slides = load_photos_from_json("../data/horizontal_photos.json")
v_slides = create_vertical_slides(random_pair_vertical_photos, v_photos)
slides = v_slides + h_slides
slideshow = mixed_slideshow(slides)
score = total_score(slideshow)
print(score)
# Out:
# 385073

# %% [markdown]
# ### Similar Vertical photos

# %%
v_photos = load_photos_from_json("../data/vertical_photos.json")
h_slides = load_photos_from_json("../data/horizontal_photos.json")
v_slides = create_vertical_slides(similar_pair_vertical_photos, v_photos)
slides = v_slides + h_slides
slideshow = mixed_slideshow(slides)
score = total_score(slideshow)
print(score)
# Out:
# 346490

# %% [markdown]
# ### Different Vertical photos

# %%
v_photos = load_photos_from_json("../data/vertical_photos.json")
h_slides = load_photos_from_json("../data/horizontal_photos.json")
v_slides = create_vertical_slides(different_pair_vertical_photos, v_photos)
slides = v_slides + h_slides
slideshow = mixed_slideshow(slides)
score = total_score(slideshow)
print(score)
# Out:
# 414179

# %% [markdown]
# ## Compare afficiency of all methods
#
# |           | Random | Nearest neighbor | Grouped by tags | Mixed  |
# |-----------|--------|------------------|-----------------|--------|
# | Random    | 174829 | 342730           | 224602          | 385073 |
# | Similar   | 141494 | 302256           | 192229          | 346490 |
# | Different | 187609 | 371787           | 241378          | 414179 |
#
# Max result - 415180
